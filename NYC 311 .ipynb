# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing a 311 NYC service request

# %%
nyc = pd.read_csv("311_Service_Requests_from_2010_to_Present.csv")

# %%
nyc.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
nyc.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
#  11  Cross Street 1                  251419 non-null  object
# ...

# %%
nyc.shape
# Out:
# (300698, 53)

# %%
nyc["Unique Key"].value_counts().head(10)
# Out:
# 32310363    1
# 30964902    1
# 30963768    1
# 30961544    1
# 30964777    1
# 30964204    1
# 30966940    1
# 30967363    1
# 30961554    1
# 30962651    1
# Name: Unique Key, dtype: int64

# %%
#Dropping Unique key as each entry is different
#Storing data in a new dataframe

mod_nyc=nyc.drop(columns=['Unique Key'])

# %%
mod_nyc.columns
# Out:
# Index(['Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
nyc["Agency"].value_counts()
# Out:
# NYPD    300698
# Name: Agency, dtype: int64

# %%
nyc["Agency"].unique()
# Out:
# array(['NYPD'], dtype=object)

# %%
#Dropping Agency column as there is repetition of one attribute

mod_nyc=mod_nyc.drop(columns=["Agency"])

# %%
mod_nyc.columns
# Out:
# Index(['Created Date', 'Closed Date', 'Agency Name', 'Complaint Type',
#        'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address',
#        'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
nyc["Agency Name"].value_counts()
# Out:
# New York City Police Department    300690
# Internal Affairs Bureau                 6
# NYPD                                    2
# Name: Agency Name, dtype: int64

# %%
nyc["Complaint Type"].value_counts().head()
# Out:
# Blocked Driveway           77044
# Illegal Parking            75361
# Noise - Street/Sidewalk    48612
# Noise - Commercial         35577
# Derelict Vehicle           17718
# Name: Complaint Type, dtype: int64

# %%
nyc["Descriptor"].value_counts().head()
# Out:
# Loud Music/Party                 61430
# No Access                        56976
# Posted Parking Sign Violation    22440
# Loud Talking                     21584
# Partial Access                   20068
# Name: Descriptor, dtype: int64

# %%
nyc["Location Type"].value_counts()
# Out:
# Street/Sidewalk               249299
# Store/Commercial               20381
# Club/Bar/Restaurant            17360
# Residential Building/House      6960
# Park/Playground                 4773
# House of Worship                 929
# Residential Building             227
# Highway                          215
# Parking Lot                      117
# House and Store                   93
# Vacant Lot                        77
# Commercial                        62
# Roadway Tunnel                    35
# Subway Station                    34
# Bridge                             2
# Terminal                           1
# Ferry                              1
# Park                               1
# Name: Location Type, dtype: int64

# %%
nyc["Incident Zip"].value_counts().head()
# Out:
# 11385.0    5167
# 11368.0    4298
# 11211.0    4225
# 11234.0    4150
# 11206.0    3781
# Name: Incident Zip, dtype: int64

# %%
nyc["Incident Address"].value_counts().head()
# Out:
# 1207 BEACH AVENUE          904
# 78-15 PARSONS BOULEVARD    505
# 89 MOORE STREET            480
# 177 LAREDO AVENUE          311
# 2117 3 AVENUE              295
# Name: Incident Address, dtype: int64

# %%
nyc["Street Name"].value_counts().head()
# Out:
# BROADWAY          3237
# 3 AVENUE          1241
# SHERMAN AVENUE    1156
# BEACH AVENUE      1109
# BEDFORD AVENUE     979
# Name: Street Name, dtype: int64

# %%
nyc["Cross Street 1"].value_counts().head()
# Out:
# BROADWAY            4338
# BEND                4129
# 3 AVENUE            3112
# 5 AVENUE            3035
# AMSTERDAM AVENUE    2651
# Name: Cross Street 1, dtype: int64

# %%
nyc["Cross Street 2"].value_counts().head()
# Out:
# BEND        4391
# BROADWAY    3784
# 8 AVENUE    2766
# DEAD END    2144
# 7 AVENUE    2140
# Name: Cross Street 2, dtype: int64

# %%
nyc["Intersection Street 1"].value_counts().head()
# Out:
# BROADWAY      672
# 170 STREET    441
# 44 STREET     355
# 6 AVENUE      348
# 85 STREET     237
# Name: Intersection Street 1, dtype: int64

# %%
nyc["Intersection Street 2"].value_counts().head()
# Out:
# BROADWAY    1358
# 6 AVENUE     715
# 2 AVENUE     617
# 5 AVENUE     551
# 3 AVENUE     487
# Name: Intersection Street 2, dtype: int64

# %%
nyc["Address Type"].value_counts()
# Out:
# ADDRESS         238644
# INTERSECTION     43366
# BLOCKFACE        12014
# LATLONG           3509
# PLACENAME          350
# Name: Address Type, dtype: int64

# %%
nyc["City"].value_counts().head()
# Out:
# BROOKLYN         98307
# NEW YORK         65994
# BRONX            40702
# STATEN ISLAND    12343
# JAMAICA           7296
# Name: City, dtype: int64

# %%
nyc["Landmark"].value_counts().head()
# Out:
# CENTRAL PARK              67
# PROSPECT PARK             22
# WASHINGTON SQUARE PARK    16
# SUNSET PARK               13
# UNION SQUARE PARK         13
# Name: Landmark, dtype: int64

# %%
nyc["Facility Type"].value_counts()   #Need to drop this column as only one unique value
# Out:
# Precinct    298527
# Name: Facility Type, dtype: int64

# %%
nyc["Status"].value_counts()
# Out:
# Closed      298471
# Open          1439
# Assigned       786
# Draft            2
# Name: Status, dtype: int64

# %%
nyc["Due Date"].value_counts().head()
# Out:
# 11-07-15 7:34    9
# 06-07-15 6:23    9
# 07-12-15 7:04    9
# 11-02-15 6:12    8
# 05-03-15 9:32    8
# Name: Due Date, dtype: int64

# %%
nyc["Resolution Description"].value_counts()
# Out:
# The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.                                                                                                                                                                                                                                                                                                                                                                               90490
# ...

# %%
nyc["Resolution Action Updated Date"].value_counts().head()
# Out:
# 11-08-15 7:34     24
# 10-11-15 7:03     22
# 05-10-15 7:01     18
# 12-08-15 7:44     18
# 12-07-15 23:17    17
# Name: Resolution Action Updated Date, dtype: int64

# %%
nyc["Community Board"].value_counts().head()
# Out:
# 12 MANHATTAN    12390
# 01 BROOKLYN     10920
# 05 QUEENS        9422
# 01 QUEENS        9197
# 09 QUEENS        8013
# Name: Community Board, dtype: int64

# %%
nyc["Borough"].value_counts()
# Out:
# BROOKLYN         98307
# QUEENS           80641
# MANHATTAN        66131
# BRONX            40702
# STATEN ISLAND    12343
# Unspecified       2574
# Name: Borough, dtype: int64

# %%
nyc["X Coordinate (State Plane)"].value_counts().head()
# Out:
# 1021327.0    911
# 1000311.0    563
# 1037000.0    507
# 982967.0     344
# 1042290.0    342
# Name: X Coordinate (State Plane), dtype: int64

# %%
nyc["Y Coordinate (State Plane)"].value_counts().head()
# Out:
# 241829.0    902
# 202363.0    506
# 195702.0    500
# 175044.0    364
# 197554.0    345
# Name: Y Coordinate (State Plane), dtype: int64

# %%
nyc["Park Facility Name"].value_counts()
# Out:
# Unspecified                        300697
# Alley Pond Park - Nature Center         1
# Name: Park Facility Name, dtype: int64

# %%
nyc["Park Facility Name"].unique() #suspected liability to be dropped
# Out:
# array(['Unspecified', 'Alley Pond Park - Nature Center'], dtype=object)

# %%
nyc["Park Borough"].value_counts()
# Out:
# BROOKLYN         98307
# QUEENS           80641
# MANHATTAN        66131
# BRONX            40702
# STATEN ISLAND    12343
# Unspecified       2574
# Name: Park Borough, dtype: int64

# %%
mod_nyc=mod_nyc.drop(columns=["Park Facility Name","Facility Type"],axis=1)

# %%
mod_nyc.shape
# Out:
# (300698, 49)

# %%
nyc["School Name"].value_counts()
# Out:
# Unspecified                        300697
# Alley Pond Park - Nature Center         1
# Name: School Name, dtype: int64

# %%
nyc["School Number"].value_counts()
# Out:
# Unspecified    300697
# Q001                1
# Name: School Number, dtype: int64

# %%
nyc["School Region"].value_counts()
# Out:
# Unspecified    300697
# Name: School Region, dtype: int64

# %%
nyc["School Not Found"].value_counts()
# Out:
# N    300698
# Name: School Not Found, dtype: int64

# %%
nyc["School Phone Number"].value_counts()
# Out:
# Unspecified    300697
# 7182176034          1
# Name: School Phone Number, dtype: int64

# %%
nyc["School Address"].value_counts()
# Out:
# Unspecified                                     300697
# Grand Central Parkway, near the soccer field         1
# Name: School Address, dtype: int64

# %%
nyc["School City"].value_counts()
# Out:
# Unspecified    300697
# QUEENS              1
# Name: School City, dtype: int64

# %%
nyc["School State"].value_counts()
# Out:
# Unspecified    300697
# NY                  1
# Name: School State, dtype: int64

# %%
nyc["School Zip"].value_counts()
# Out:
# Unspecified    300697
# Name: School Zip, dtype: int64

# %%
nyc["School Not Found"].value_counts()
# Out:
# N    300698
# Name: School Not Found, dtype: int64

# %%
mod_nyc=mod_nyc.drop(columns=["School Name","School Number", "School Region","School Code","School Phone Number","School Address","School City","School State","School Zip","School Not Found"],axis=1)

# %%
mod_nyc.shape
# Out:
# (300698, 39)

# %%
nyc["School or Citywide Complaint"].value_counts()
# Out:
# Series([], Name: School or Citywide Complaint, dtype: int64)

# %%
nyc["Vehicle Type"].value_counts()
# Out:
# Series([], Name: Vehicle Type, dtype: int64)

# %%
nyc["Taxi Company Borough"].value_counts()
# Out:
# Series([], Name: Taxi Company Borough, dtype: int64)

# %%
nyc["Taxi Pick Up Location"].value_counts()
# Out:
# Series([], Name: Taxi Pick Up Location, dtype: int64)

# %%
nyc["Bridge Highway Name"].value_counts().head()
# Out:
# FDR Dr                 33
# Belt Pkwy              30
# BQE/Gowanus Expwy      27
# Staten Island Expwy    21
# Cross Bronx Expwy      19
# Name: Bridge Highway Name, dtype: int64

# %%
nyc["Bridge Highway Direction"].value_counts().head()
# Out:
# East/Queens Bound             21
# Northbound/Uptown             20
# North/Bronx Bound             20
# West/Staten Island Bound      18
# North/Westbound (To GW Br)    17
# Name: Bridge Highway Direction, dtype: int64

# %%
nyc["Road Ramp"].value_counts()
# Out:
# Roadway    162
# Ramp        51
# Name: Road Ramp, dtype: int64

# %%
nyc["Bridge Highway Segment"].value_counts().head()
# Out:
# East 96th St (Exit 14) - Triborough Br (Exit 17)                              6
# Bronx River Pkwy (Exit 4B) - Westchester Ave / White Plains Road (Exit 5A)    5
# Westchester Ave / White Plains Road (Exit 5A) - Castle Hill Ave (Exit 5B)     3
# Richmond Ave (Exit 7) - Victory Blvd (Exit 8)                                 3
# BEGIN Staten Island Expwy (Exit 15N) - Lily Pond Ave/Bay St (Exit 15S)        3
# Name: Bridge Highway Segment, dtype: int64

# %%
nyc["Garage Lot Name"].value_counts()
# Out:
# Series([], Name: Garage Lot Name, dtype: int64)

# %%
nyc["Ferry Direction"].value_counts()
# Out:
# Manhattan Bound    1
# Name: Ferry Direction, dtype: int64

# %%
nyc["Ferry Terminal Name"].value_counts()
# Out:
# St. George Terminal (Staten Island)    1
# Barberi                                1
# Name: Ferry Terminal Name, dtype: int64

# %%
nyc["Longitude"].value_counts().head()
# Out:
# -73.866022    902
# -73.809697    505
# -73.942073    480
# -73.790654    341
# -74.004623    340
# Name: Longitude, dtype: int64

# %%
nyc["Location"].value_counts().head()
# Out:
# (40.83036235589997, -73.86602154214397)     902
# (40.72195913199264, -73.80969682426189)     505
# (40.703818970933284, -73.94207345177706)    476
# (40.708726489323325, -73.7906539235748)     341
# (40.64713190020787, -74.00462341153786)     340
# Name: Location, dtype: int64

# %%
# Creating new Dataframe by dropping insignificant columns

# %%
mod_nyc=mod_nyc.drop(columns=["School or Citywide Complaint","Vehicle Type","Taxi Company Borough","Taxi Pick Up Location","Garage Lot Name","Ferry Direction","Ferry Terminal Name"])

# %%
mod_nyc.shape
# Out:
# (300698, 32)

# %%
mod_nyc.columns
# Out:
# Index(['Created Date', 'Closed Date', 'Agency Name', 'Complaint Type',
#        'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address',
#        'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Status', 'Due Date', 'Resolution Description',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Borough', 'Bridge Highway Name', 'Bridge Highway Direction',
#        'Road Ramp', 'Bridge Highway Segment', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
mod_nyc.head()
# Out:
#              Created Date    Closed Date                      Agency Name  \
# 0  12/31/2015 11:59:45 PM  01-01-16 0:55  New York City Police Department
# 1  12/31/2015 11:59:44 PM  01-01-16 1:26  New York City Police Department
# 2  12/31/2015 11:59:29 PM  01-01-16 4:51  New York City Police Department
# 3  12/31/2015 11:57:46 PM  01-01-16 7:43  New York City Police Department
# 4  12/31/2015 11:56:58 PM  01-01-16 3:24  New York City Police Department
#
#             Complaint Type                    Descriptor    Location Type  \
# 0  Noise - Street/Sidewalk              Loud Music/Party  Street/Sidewalk
# 1         Blocked Driveway                     No Access  Street/Sidewalk
# 2         Blocked Driveway                     No Access  Street/Sidewalk
# 3          Illegal Parking  Commercial Overnight Parking  Street/Sidewalk
# 4          Illegal Parking              Blocked Sidewalk  Street/Sidewalk
#
# ...

# %%
pd.set_option("Display.max_columns", None)

# %%
mod_nyc.sample(5)
# Out:
#                   Created Date             Closed Date  \
# 279386  04/22/2015 12:06:29 AM  04/22/2015 03:11:23 AM
# 108062  09/19/2015 10:01:04 AM  09/19/2015 10:51:31 AM
# 24660           12-06-15 20:10          12-06-15 21:10
# 43205   11/18/2015 03:30:40 AM  11/18/2015 03:52:45 AM
# 70294   10/23/2015 12:00:52 PM  10/23/2015 03:25:12 PM
#
#                             Agency Name           Complaint Type  \
# 279386  New York City Police Department  Noise - Street/Sidewalk
# 108062  New York City Police Department         Derelict Vehicle
# 24660   New York City Police Department          Illegal Parking
# 43205   New York City Police Department          Illegal Parking
# 70294   New York City Police Department         Blocked Driveway
#
#                 Descriptor    Location Type  Incident Zip  \
# 279386        Loud Talking  Street/Sidewalk       10031.0
# 108062  With License Plate  Street/Sidewalk       11235.0
# 24660      Blocked Hydrant  Street/Sidewalk       11374.0
# ...

# %% [markdown]
# # As per above info created and closed date are in object form,need to convert them into datetime form and creating new column named Request_Closing_Time in secs for further analysis

# %%
# Coverting the type of Date  from object to DateTime format

# %%
import pandas as pd

# %%
mod_nyc['Created Date'] = pd.to_datetime(mod_nyc['Created Date'])
mod_nyc['Closed Date'] = pd.to_datetime(mod_nyc['Closed Date'])
mod_nyc['Request_Closing_Time'] = mod_nyc['Closed Date'] - mod_nyc['Created Date']

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
#  11  Cross Street 1                  251419 non-null  object
# ...

# %%
mod_nyc.head(1)
# Out:
#          Created Date         Closed Date                      Agency Name  \
# 0 2015-12-31 23:59:45 2016-01-01 00:55:00  New York City Police Department
#
#             Complaint Type        Descriptor    Location Type  Incident Zip  \
# 0  Noise - Street/Sidewalk  Loud Music/Party  Street/Sidewalk       10034.0
#
#       Incident Address       Street Name  Cross Street 1   Cross Street 2  \
# 0  71 VERMILYEA AVENUE  VERMILYEA AVENUE  ACADEMY STREET  WEST 204 STREET
#
#   Intersection Street 1 Intersection Street 2 Address Type      City Landmark  \
# 0                   NaN                   NaN      ADDRESS  NEW YORK      NaN
#
#    Status       Due Date                             Resolution Description  \
# 0  Closed  01-01-16 7:59  The Police Department responded and upon arriv...
#
#   Resolution Action Updated Date Community Board    Borough  \
# 0                  01-01-16 0:55    12 MANHATTAN  MANHATTAN
#
# ...

# %%
mod_nyc['Request_Closing_Time_insec'] = mod_nyc['Request_Closing_Time'].dt.seconds
nyc.head(1)
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#      Location Type  Incident Zip     Incident Address       Street Name  \
# 0  Street/Sidewalk       10034.0  71 VERMILYEA AVENUE  VERMILYEA AVENUE
#
#    Cross Street 1   Cross Street 2 Intersection Street 1  \
# 0  ACADEMY STREET  WEST 204 STREET                   NaN
#
#   Intersection Street 2 Address Type      City Landmark Facility Type  Status  \
# 0                   NaN      ADDRESS  NEW YORK      NaN      Precinct  Closed
#
#         Due Date                             Resolution Description  \
# 0  01-01-16 7:59  The Police Department responded and upon arriv...
#
#   Resolution Action Updated Date Community Board    Borough  \
# ...

# %%
nyc.head(1)
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#      Location Type  Incident Zip     Incident Address       Street Name  \
# 0  Street/Sidewalk       10034.0  71 VERMILYEA AVENUE  VERMILYEA AVENUE
#
#    Cross Street 1   Cross Street 2 Intersection Street 1  \
# 0  ACADEMY STREET  WEST 204 STREET                   NaN
#
#   Intersection Street 2 Address Type      City Landmark Facility Type  Status  \
# 0                   NaN      ADDRESS  NEW YORK      NaN      Precinct  Closed
#
#         Due Date                             Resolution Description  \
# 0  01-01-16 7:59  The Police Department responded and upon arriv...
#
#   Resolution Action Updated Date Community Board    Borough  \
# ...

# %%
mod_nyc.describe().round()
# Out:
#        Incident Zip  X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# count      298083.0                    297158.0                    297158.0
# mean        10849.0                   1004854.0                    203755.0
# std           583.0                     21753.0                     29880.0
# min            83.0                    913357.0                    121219.0
# 25%         10310.0                    991975.0                    183343.0
# 50%         11208.0                   1003158.0                    201110.0
# 75%         11238.0                   1018372.0                    224125.0
# max         11697.0                   1067173.0                    271876.0
#
#        Latitude  Longitude       Request_Closing_Time  \
# count  297158.0   297158.0                     298534
# mean       41.0      -74.0  0 days 04:18:51.832782865
# std         0.0        0.0  0 days 06:05:22.141833856
# min        40.0      -74.0            0 days 00:01:00
# ...

# %%
mod_nyc.head()
# Out:
#          Created Date         Closed Date                      Agency Name  \
# 0 2015-12-31 23:59:45 2016-01-01 00:55:00  New York City Police Department
# 1 2015-12-31 23:59:44 2016-01-01 01:26:00  New York City Police Department
# 2 2015-12-31 23:59:29 2016-01-01 04:51:00  New York City Police Department
# 3 2015-12-31 23:57:46 2016-01-01 07:43:00  New York City Police Department
# 4 2015-12-31 23:56:58 2016-01-01 03:24:00  New York City Police Department
#
#             Complaint Type                    Descriptor    Location Type  \
# 0  Noise - Street/Sidewalk              Loud Music/Party  Street/Sidewalk
# 1         Blocked Driveway                     No Access  Street/Sidewalk
# 2         Blocked Driveway                     No Access  Street/Sidewalk
# 3          Illegal Parking  Commercial Overnight Parking  Street/Sidewalk
# 4          Illegal Parking              Blocked Sidewalk  Street/Sidewalk
#
# ...

# %% [markdown]
# # Creating insights

# %%
insight1 = nyc[['Complaint Type' , 'Agency']].groupby('Complaint Type').count()
insight1
# Out:
#                            Agency
# Complaint Type
# Agency Issues                   6
# Animal Abuse                 7778
# Animal in a Park                1
# Bike/Roller/Skate Chronic     427
# Blocked Driveway            77044
# Derelict Vehicle            17718
# Disorderly Youth              286
# Drinking                     1280
# Ferry Complaint                 2
# Graffiti                      113
# Homeless Encampment          4416
# Illegal Fireworks             168
# Illegal Parking             75361
# Noise - Commercial          35577
# Noise - House of Worship      931
# Noise - Park                 4042
# Noise - Street/Sidewalk     48612
# Noise - Vehicle             17083
# Panhandling                   307
# Posting Advertisement         650
# Squeegee                        4
# Traffic                      4498
# Urinating in Public           592
# Vending                      3802

# %%
insight1.rename(columns={'Agency':'Entries'},inplace=True)
insight1
# Out:
#                            Entries
# Complaint Type
# Agency Issues                    6
# Animal Abuse                  7778
# Animal in a Park                 1
# Bike/Roller/Skate Chronic      427
# Blocked Driveway             77044
# Derelict Vehicle             17718
# Disorderly Youth               286
# Drinking                      1280
# Ferry Complaint                  2
# Graffiti                       113
# Homeless Encampment           4416
# Illegal Fireworks              168
# Illegal Parking              75361
# Noise - Commercial           35577
# Noise - House of Worship       931
# Noise - Park                  4042
# Noise - Street/Sidewalk      48612
# Noise - Vehicle              17083
# Panhandling                    307
# Posting Advertisement          650
# Squeegee                         4
# Traffic                       4498
# Urinating in Public            592
# Vending                       3802

# %%
insight1.sort_values('Entries',inplace=True,ascending=False)
insight1
# Out:
#                            Entries
# Complaint Type
# Blocked Driveway             77044
# Illegal Parking              75361
# Noise - Street/Sidewalk      48612
# Noise - Commercial           35577
# Derelict Vehicle             17718
# Noise - Vehicle              17083
# Animal Abuse                  7778
# Traffic                       4498
# Homeless Encampment           4416
# Noise - Park                  4042
# Vending                       3802
# Drinking                      1280
# Noise - House of Worship       931
# Posting Advertisement          650
# Urinating in Public            592
# Bike/Roller/Skate Chronic      427
# Panhandling                    307
# Disorderly Youth               286
# Illegal Fireworks              168
# Graffiti                       113
# Agency Issues                    6
# Squeegee                         4
# Ferry Complaint                  2
# Animal in a Park                 1

# %%
for x in['Complaint Type','Location Type','Agency Name','City','Status']:
    print(x)
    print(nyc[x].value_counts().head(20))
# Out:
# Complaint Type
# Blocked Driveway             77044
# Illegal Parking              75361
# Noise - Street/Sidewalk      48612
# Noise - Commercial           35577
# Derelict Vehicle             17718
# Noise - Vehicle              17083
# Animal Abuse                  7778
# Traffic                       4498
# Homeless Encampment           4416
# Noise - Park                  4042
# Vending                       3802
# Drinking                      1280
# Noise - House of Worship       931
# Posting Advertisement          650
# Urinating in Public            592
# Bike/Roller/Skate Chronic      427
# Panhandling                    307
# Disorderly Youth               286
# Illegal Fireworks              168
# Graffiti                       113
# Name: Complaint Type, dtype: int64
# Location Type
# Street/Sidewalk               249299
# Store/Commercial               20381
# Club/Bar/Restaurant            17360
# Residential Building/House      6960
# ...

# %%
insight2 = nyc[['Location Type' , 'Agency']].groupby('Location Type').count()
insight2.rename(columns={'Agency':'Entries'},inplace=True)
insight2.sort_values('Entries',inplace=True,ascending=False)
insight2
# Out:
#                             Entries
# Location Type
# Street/Sidewalk              249299
# Store/Commercial              20381
# Club/Bar/Restaurant           17360
# Residential Building/House     6960
# Park/Playground                4773
# House of Worship                929
# Residential Building            227
# Highway                         215
# Parking Lot                     117
# House and Store                  93
# Vacant Lot                       77
# Commercial                       62
# Roadway Tunnel                   35
# Subway Station                   34
# Bridge                            2
# Park                              1
# Ferry                             1
# Terminal                          1

# %%
insight3 = nyc[['City' , 'Agency']].groupby('City').count()
insight3.rename(columns={'Agency':'Entries'},inplace=True)
insight3.sort_values('Entries',inplace=True,ascending=False)
insight3
# Out:
#                      Entries
# City
# BROOKLYN               98307
# NEW YORK               65994
# BRONX                  40702
# STATEN ISLAND          12343
# JAMAICA                 7296
# ASTORIA                 6330
# FLUSHING                5971
# RIDGEWOOD               5163
# CORONA                  4295
# WOODSIDE                3544
# SOUTH RICHMOND HILL     2774
# OZONE PARK              2755
# EAST ELMHURST           2734
# ELMHURST                2673
# WOODHAVEN               2464
# MASPETH                 2462
# LONG ISLAND CITY        2437
# SOUTH OZONE PARK        2173
# RICHMOND HILL           1904
# FRESH MEADOWS           1899
# QUEENS VILLAGE          1814
# MIDDLE VILLAGE          1765
# JACKSON HEIGHTS         1689
# FOREST HILLS            1688
# REGO PARK               1486
# BAYSIDE                 1221
# COLLEGE POINT           1220
# FAR ROCKAWAY            1179
# WHITESTONE              1098
# HOLLIS                  1012
# HOWARD BEACH             931
# ...

# %%
insight4 = nyc[['Status' , 'Agency']].groupby('Status').count()
insight4.rename(columns={'Agency':'Entries'},inplace=True)
insight4.sort_values('Entries',inplace=True,ascending=False)
insight4
# Out:
#           Entries
# Status
# Closed     298471
# Open         1439
# Assigned      786
# Draft           2

# %%
insight5 = nyc[['Complaint Type','Location Type','Status', 'Agency']].groupby(['Location Type','Complaint Type','Status']).count()
insight5.rename(columns={'Agency':'Entries'},inplace=True)
insight5.sort_values('Entries',inplace=True,ascending=False)
insight5
# Out:
#                                                                Entries
# Location Type              Complaint Type            Status
# Street/Sidewalk            Blocked Driveway          Closed      76773
#                            Illegal Parking           Closed      74497
#                            Noise - Street/Sidewalk   Closed      48067
# Store/Commercial           Noise - Commercial        Closed      18401
# Street/Sidewalk            Derelict Vehicle          Closed      17485
# ...                                                                ...
#                            Posting Advertisement     Open            1
# Residential Building/House Bike/Roller/Skate Chronic Open            1
# Street/Sidewalk            Posting Advertisement     Assigned        1
#                            Panhandling               Open            1
#                            Noise - Street/Sidewalk   Draft           1
#
# [109 rows x 1 columns]

# %%
pd.set_option('display.max_rows',None)
insight5
# Out:
#                                                                Entries
# Location Type              Complaint Type            Status
# Street/Sidewalk            Blocked Driveway          Closed      76773
#                            Illegal Parking           Closed      74497
#                            Noise - Street/Sidewalk   Closed      48067
# Store/Commercial           Noise - Commercial        Closed      18401
# Street/Sidewalk            Derelict Vehicle          Closed      17485
#                            Noise - Vehicle           Closed      17030
# Club/Bar/Restaurant        Noise - Commercial        Closed      16841
# Residential Building/House Animal Abuse              Closed       5081
# Street/Sidewalk            Traffic                   Closed       4276
# Park/Playground            Noise - Park              Closed       4021
# Street/Sidewalk            Vending                   Closed       3055
# ...

# %%
location_grouping = nyc['Location Type'].value_counts()
location_grouping
# Out:
# Street/Sidewalk               249299
# Store/Commercial               20381
# Club/Bar/Restaurant            17360
# Residential Building/House      6960
# Park/Playground                 4773
# House of Worship                 929
# Residential Building             227
# Highway                          215
# Parking Lot                      117
# House and Store                   93
# Vacant Lot                        77
# Commercial                        62
# Roadway Tunnel                    35
# Subway Station                    34
# Bridge                             2
# Terminal                           1
# Ferry                              1
# Park                               1
# Name: Location Type, dtype: int64

# %%
location_grouping = nyc.groupby(['Location Type'])
Grouping = location_grouping['Complaint Type'].value_counts()
pd.set_option('display.max_rows',None)
Grouping
# Out:
# Location Type               Complaint Type
# Bridge                      Homeless Encampment              2
# Club/Bar/Restaurant         Noise - Commercial           16973
#                             Drinking                       366
#                             Urinating in Public             21
# Commercial                  Animal Abuse                    62
# Ferry                       Ferry Complaint                  1
# Highway                     Traffic                        186
#                             Homeless Encampment             15
#                             Derelict Vehicle                14
# House and Store             Animal Abuse                    93
# House of Worship            Noise - House of Worship       929
# Park                        Animal in a Park                 1
# Park/Playground             Noise - Park                  4041
#                             Homeless Encampment            353
# ...

# %%
Grouping.shape
# Out:
# (71,)

# %% [markdown]
# # Data Visualization

# %%
insight1.plot(kind='bar')
plt.xlabel('Complaint Type', rotation=45)
plt.ylabel('No of Complaint', rotation=90)
plt.title('insight1 - analysis of compalint')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
insight2.plot(kind='line')
plt.xlabel('Location Type')
plt.ylabel('No of Complaint')
plt.title('insight2 - analysis of compalaint by Location')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
insight2.plot(kind='bar')
plt.xlabel('Location Type')
plt.ylabel('No of Complaint')
plt.title('insight2 - analysis of compalint by Location')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure(figsize = (300,10), dpi = 1080)
insight3.plot(kind='bar')
plt.xlabel('city')
plt.ylabel('No of Complaints')
plt.xticks(rotation = 90, color = 'red', size = 7, alpha = 0.5)
plt.title('Insight 3 city wise complaint')
plt.show()

# %%
fig = plt.figure(figsize = (12,5), dpi = 1080)
insight4.plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('No of Complaints')
plt.title('Insight- Status of complaints')
plt.show()

# %%
mod_nyc.head()
# Out:
#          Created Date         Closed Date                      Agency Name  \
# 0 2015-12-31 23:59:45 2016-01-01 00:55:00  New York City Police Department
# 1 2015-12-31 23:59:44 2016-01-01 01:26:00  New York City Police Department
# 2 2015-12-31 23:59:29 2016-01-01 04:51:00  New York City Police Department
# 3 2015-12-31 23:57:46 2016-01-01 07:43:00  New York City Police Department
# 4 2015-12-31 23:56:58 2016-01-01 03:24:00  New York City Police Department
#
#             Complaint Type                    Descriptor    Location Type  \
# 0  Noise - Street/Sidewalk              Loud Music/Party  Street/Sidewalk
# 1         Blocked Driveway                     No Access  Street/Sidewalk
# 2         Blocked Driveway                     No Access  Street/Sidewalk
# 3          Illegal Parking  Commercial Overnight Parking  Street/Sidewalk
# 4          Illegal Parking              Blocked Sidewalk  Street/Sidewalk
#
# ...

# %%
nyc_rct=mod_nyc[['City','Complaint Type','Request_Closing_Time']]
nyc_rct.dropna(subset=['City','Complaint Type','Request_Closing_Time'],inplace=True)
nyc_rct.isna().any()
# Out:
# City                    False
# Complaint Type          False
# Request_Closing_Time    False
# dtype: bool

# %%
dt=nyc_rct['Request_Closing_Time']

# %%
nyc_rct['Time(hr)']=np.around((nyc_rct['Request_Closing_Time'].astype(np.int64)/(pow(10,9)*3600)), decimals=2)
nyc_rct.head()
# Out:
#        City           Complaint Type Request_Closing_Time  Time(hr)
# 0  NEW YORK  Noise - Street/Sidewalk      0 days 00:55:15      0.92
# 1   ASTORIA         Blocked Driveway      0 days 01:26:16      1.44
# 2     BRONX         Blocked Driveway      0 days 04:51:31      4.86
# 3     BRONX          Illegal Parking      0 days 07:45:14      7.75
# 4  ELMHURST          Illegal Parking      0 days 03:27:02      3.45

# %%
rct_avg=np.around(nyc_rct['Time(hr)'].mean(), decimals=2)
rct_dev=np.around(nyc_rct["Time(hr)"].std(), decimals=2)
rct_med=np.around(nyc_rct["Time(hr)"].median(), decimals=2)
rct_mod=np.around(nyc_rct["Time(hr)"].mode(), decimals=2)

print(f"Average Time to respond is {rct_avg} hr")
print(f" Std Dev Time is {rct_dev} hr")
print(f"Median is {rct_med} hr")
print(f"Mode is {rct_mod} hr")
# Out:
# Average Time to respond is 4.31 hr
#  Std Dev Time is 6.08 hr
# Median is 2.71 hr
# Mode is 0    0.88
# Name: Time(hr), dtype: float64 hr

# %%
cond_list=[nyc_rct['Time(hr)']<=1.0, 
           (1.0<nyc_rct['Time(hr)']) & (nyc_rct['Time(hr)']<=2.0),
           (2.0<nyc_rct['Time(hr)']) & (nyc_rct['Time(hr)']<=3.0), 
           (3.0<nyc_rct['Time(hr)']) & (nyc_rct['Time(hr)']<=6.0),
           (6.0<nyc_rct['Time(hr)']) & (nyc_rct['Time(hr)']<=8.0),
           nyc_rct['Time(hr)']>8.0]

choice_list=['Super Fast','Very Fast', 'Fast', 'Normal','Slow','Very Slow']
nyc_rct['Response Status']=np.select(cond_list,choice_list )

# %%
nyc_rct.sample(5)
# Out:
#                  City           Complaint Type Request_Closing_Time  Time(hr)  \
# 188208  STATEN ISLAND  Noise - Street/Sidewalk      0 days 00:21:00      0.35
# 151179       BROOKLYN       Noise - Commercial      0 days 02:43:04      2.72
# 261425  STATEN ISLAND  Noise - Street/Sidewalk      0 days 01:56:00      1.93
# 6264            BRONX         Blocked Driveway      0 days 02:48:14      2.80
# 10316        BROOKLYN         Derelict Vehicle      0 days 07:25:26      7.42
#
#        Response Status
# 188208      Super Fast
# 151179            Fast
# 261425       Very Fast
# 6264              Fast
# 10316             Slow

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,3))
sns.countplot(x='Response Status', data=nyc_rct ,palette='Set1')
plt.title("Frequency of different Responses")
plt.show()

# %% [markdown]
# # Ordering the complaint based on Avg Response Time & Location

# %%
nyc_rct.head()
# Out:
#        City           Complaint Type Request_Closing_Time  Time(hr)  \
# 0  NEW YORK  Noise - Street/Sidewalk      0 days 00:55:15      0.92
# 1   ASTORIA         Blocked Driveway      0 days 01:26:16      1.44
# 2     BRONX         Blocked Driveway      0 days 04:51:31      4.86
# 3     BRONX          Illegal Parking      0 days 07:45:14      7.75
# 4  ELMHURST          Illegal Parking      0 days 03:27:02      3.45
#
#   Response Status
# 0      Super Fast
# 1       Very Fast
# 2          Normal
# 3            Slow
# 4          Normal

# %%
order_RCT=nyc_rct.groupby(['City','Complaint Type']) [['Time(hr)']].mean()
order_RCT.head()
# Out:
#                           Time(hr)
# City    Complaint Type
# ARVERNE Animal Abuse      2.153158
#         Blocked Driveway  2.526286
#         Derelict Vehicle  2.968519
#         Disorderly Youth  3.595000
#         Drinking          0.240000

# %%
type(order_RCT)
# Out:
# pandas.core.frame.DataFrame

# %%
order_RCT=order_RCT.sort_values(by=["City","Time(hr)"])
order_RCT=order_RCT.reset_index()

order_RCT.head()
# Out:
#       City       Complaint Type  Time(hr)
# 0  ARVERNE             Drinking     0.240
# 1  ARVERNE              Vending     0.480
# 2  ARVERNE  Urinating in Public     0.690
# 3  ARVERNE          Panhandling     1.030
# 4  ARVERNE         Noise - Park     1.285

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
order_RCT
# Out:
#                     City             Complaint Type    Time(hr)
# 0                ARVERNE                   Drinking    0.240000
# 1                ARVERNE                    Vending    0.480000
# 2                ARVERNE        Urinating in Public    0.690000
# 3                ARVERNE                Panhandling    1.030000
# 4                ARVERNE               Noise - Park    1.285000
# 5                ARVERNE                   Graffiti    1.530000
# 6                ARVERNE   Noise - House of Worship    1.562727
# 7                ARVERNE        Homeless Encampment    1.812500
# 8                ARVERNE            Noise - Vehicle    1.860000
# 9                ARVERNE    Noise - Street/Sidewalk    1.992759
# 10               ARVERNE               Animal Abuse    2.153158
# 11               ARVERNE         Noise - Commercial    2.285000
# 12               ARVERNE            Illegal Parking    2.316207
# 13               ARVERNE           Blocked Driveway    2.526286
# ...

# %% [markdown]
# # Performing Statistical Test

# %%
Avg_CompType=order_RCT.groupby(['Complaint Type']) [['Time(hr)']].mean()
Avg_CompType=Avg_CompType.sort_values(by='Time(hr)').reset_index()
Avg_CompType
# Out:
#                Complaint Type    Time(hr)
# 0           Illegal Fireworks    2.393066
# 1            Disorderly Youth    3.249398
# 2    Noise - House of Worship    3.330311
# 3                Noise - Park    3.353008
# 4                    Drinking    3.567157
# 5             Noise - Vehicle    3.617984
# 6     Noise - Street/Sidewalk    3.822355
# 7          Noise - Commercial    3.850967
# 8       Posting Advertisement    3.856503
# 9         Urinating in Public    3.884093
# 10                    Traffic    3.959888
# 11                   Squeegee    4.047500
# 12                Panhandling    4.208160
# 13                    Vending    4.664614
# 14           Blocked Driveway    4.909439
# 15            Illegal Parking    5.147254
# 16  Bike/Roller/Skate Chronic    5.825729
# 17               Animal Abuse    6.168765
# 18        Homeless Encampment    6.918075
# 19                   Graffiti    7.379105
# 20           Derelict Vehicle    7.927341
# ...

# %% [markdown]
# Avg. time due to complaint type 'Animal in a Park' quite out of the range. Let's find out the average with or without this particular complaint type.

# %%
Avg_CompType1=Avg_CompType[Avg_CompType['Complaint Type']!='Animal in a Park']
Avg_CompType1.head()
# Out:
#              Complaint Type  Time(hr)
# 0         Illegal Fireworks  2.393066
# 1          Disorderly Youth  3.249398
# 2  Noise - House of Worship  3.330311
# 3              Noise - Park  3.353008
# 4                  Drinking  3.567157

# %%
T_avg=Avg_CompType1.mean()
print(f"Average Complaint Resolution time without animal in a park is {T_avg} hrs" );
# Out:
# Average Complaint Resolution time without animal in a park is Time(hr)    4.575272
# dtype: float64 hrs

# %% [markdown]
# # One Way ANOVA Test

# %%
1# Null Hypothesis: There is no significant  relationship among avg.response time across
 # varios complaint types.
 
 2# Alt. Hypothesis: There exists a significant relationship among avg.response time across
  # varios complaint types.

# %%
import scipy.stats as stat

# %%
sample1_anova=Avg_CompType1.sample(frac=1/3)
sample1_anova
# Out:
#                Complaint Type  Time(hr)
# 16  Bike/Roller/Skate Chronic  5.825729
# 10                    Traffic  3.959888
# 20           Derelict Vehicle  7.927341
# 13                    Vending  4.664614
# 1            Disorderly Youth  3.249398
# 7          Noise - Commercial  3.850967
# 2    Noise - House of Worship  3.330311

# %%
rest_data = Avg_CompType.drop(sample1_anova.index)
rest_data
# Out:
#              Complaint Type    Time(hr)
# 0         Illegal Fireworks    2.393066
# 3              Noise - Park    3.353008
# 4                  Drinking    3.567157
# 5           Noise - Vehicle    3.617984
# 6   Noise - Street/Sidewalk    3.822355
# 8     Posting Advertisement    3.856503
# 9       Urinating in Public    3.884093
# 11                 Squeegee    4.047500
# 12              Panhandling    4.208160
# 14         Blocked Driveway    4.909439
# 15          Illegal Parking    5.147254
# 17             Animal Abuse    6.168765
# 18      Homeless Encampment    6.918075
# 19                 Graffiti    7.379105
# 21         Animal in a Park  336.830000

# %%
sample2_anova = rest_data.sample(frac=1/2)
sample2_anova
# Out:
#            Complaint Type    Time(hr)
# 11               Squeegee    4.047500
# 8   Posting Advertisement    3.856503
# 4                Drinking    3.567157
# 9     Urinating in Public    3.884093
# 21       Animal in a Park  336.830000
# 17           Animal Abuse    6.168765
# 12            Panhandling    4.208160
# 15        Illegal Parking    5.147254

# %%
sample3_anova = rest_data.drop(sample2_anova.index)
sample3_anova
# Out:
#              Complaint Type  Time(hr)
# 0         Illegal Fireworks  2.393066
# 3              Noise - Park  3.353008
# 5           Noise - Vehicle  3.617984
# 6   Noise - Street/Sidewalk  3.822355
# 14         Blocked Driveway  4.909439
# 18      Homeless Encampment  6.918075
# 19                 Graffiti  7.379105

# %%
f_val, p_val=stat.f_oneway(sample1_anova['Time(hr)'], sample2_anova['Time(hr)'],sample3_anova['Time(hr)'])
print('F-statistics=', f_val)
print('p-value is=', p_val)
# Out:
# F-statistics= 0.8530653501901656
# p-value is= 0.44179334990608726

# %%
if(p_val<0.05):
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
# Out:
# Accept Null Hypothesis

# %% [markdown]
# # Chi-Square Test

# %%
#Are different types of complaint location related :

#Since both complaints & City are categorical values, we opt Chi-Square Test.

# %%
1#Null Hypothesis: There is no significant  relationship between Location &  complaint types.
 
 2#Alt. Hypothesis: There exists a significant relationship between Location & complaint types.

# %%
import scipy.stats as stat

# %%
df=mod_nyc[['Complaint Type','City']]  #df=complaint
df.head()
# Out:
#             Complaint Type      City
# 0  Noise - Street/Sidewalk  NEW YORK
# 1         Blocked Driveway   ASTORIA
# 2         Blocked Driveway     BRONX
# 3          Illegal Parking     BRONX
# 4          Illegal Parking  ELMHURST

# %%
df.isnull().sum()
# Out:
# Complaint Type       0
# City              2614
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().any()
# Out:
# Complaint Type    False
# City              False
# dtype: bool

# %%
City_Complaint=pd.crosstab(df['Complaint Type'], df['City'], margins=True, margins_name='Total')
City_Complaint.head()
# Out:
# City                       ARVERNE  ASTORIA  Astoria  BAYSIDE  BELLEROSE  \
# Complaint Type
# Animal Abuse                    38      125        0       37          7
# Animal in a Park                 0        0        0        0          0
# Bike/Roller/Skate Chronic        0       15        0        0          1
# Blocked Driveway                35     2618      116      377         95
# Derelict Vehicle                27      351       12      198         89
#
# City                       BREEZY POINT  BRONX  BROOKLYN  CAMBRIA HEIGHTS  \
# Complaint Type
# Animal Abuse                          2   1415      2394               11
# Animal in a Park                      0      0         0                0
# Bike/Roller/Skate Chronic             0     20       111                0
# Blocked Driveway                      3  12755     28148              147
# Derelict Vehicle                      3   1953      5181              115
#
# ...

# %%
chai2, p_val, df ,exp_freq= stat.chi2_contingency(City_Complaint)

# %%
print("Chai square Value is=", chai2)
print("p-value is=", p_val)
# Out:
# Chai square Value is= 119769.34666374495
# p-value is= 0.0

# %%
if(p_val<0.05):
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
# Out:
# Reject Null Hypothesis

# %%
#Since p-value is less than 0.05, we reject Null Hypothesis. This concludes that there exists a significant reltionship between Location & Complaint Type.#
